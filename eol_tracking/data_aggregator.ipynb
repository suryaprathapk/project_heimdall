# %%
import pandas as pd

# %%
informatica = pd.read_json('informatica.json')
informatica
# Out:
#   version     release_date minimum_support_period      end_of_support  \
# 0    10.5      March, 2021         March 31, 2025                 TBA
# 1    10.4   December, 2019         March 31, 2024                TBA
# 2    10.2  September, 2017     September 30, 2021  September 30, 2021
# 3  10.1.x       June, 2016          June 30, 2020  September 30, 2020
#
#      extended_support sustaining_support
# 0                 TBA                TBA
# 1                TBA                TBA
# 2  September 30,2022                TBA
# 3  September 30, 2021      Not Available

# %%
centos =pd.read_json('centos.json')
centos
# Out:
#                       version                     CentOS_6  \
# 0                                                     None
# 1
# 2                Full Updates                  2017-05-10
# 3         Maintenance Updates                  2020-11-30
# 4                                                     None
# ..                        ...                          ...
# 69              eMail Client               Evolution 2.32
# 70            Default browser                  Firefox 78
# 71              Office Suite                   Libreoffice
# 72   Multimedia capabilities    Yes (mp3 with add. repos)
# 73             Plug and Play                          Yes
#
#                       CentOS_Linux_7                    CentOS_Linux_8  \
# 0                               None                              None
# 1
# 2                        2020-08-06                        2021-12-31
# 3                        2024-06-30                        2021-12-31
# ...

# %%
apache =pd.read_json('iis.json')
apache
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-869e1a1f163f> in <module>
# ----> 1 apache =pd.read_json('iis.json')
#       2 apache
#
# c:\suryas\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# c:\suryas\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...
